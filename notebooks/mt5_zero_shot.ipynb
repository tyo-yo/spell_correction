# %%
# %cd ../../spell_correction
# Out:
# /Users/tyoyo/lab/spell_correction

# %%
from transformers import MT5ForConditionalGeneration, T5Tokenizer
model = MT5ForConditionalGeneration.from_pretrained("google/mt5-large")
tokenizer = T5Tokenizer.from_pretrained("google/mt5-large")
for p in model.parameters():
    p.requires_grad = False

# %% [markdown]
# ## Multilingualなsubword分割がどれくらい日本語で使えそうか
# * "平安"や"申し上げ"などが分割されているあたり、ある程度しっかり日本語対応できている（以前のMulti-lingual BERTではほぼcharベースだった）
# * 例外として"すもももももももものうち"は"もも"で分割されてしまうので意味的にはあまり良くない分割になっている

# %%
'", "'.join(tokenizer.tokenize('すもももももももものうち、とは平安時代に徳川家康が申し上げたものであるといわれている。'))
# Out:
# '▁", "す", "もも", "もも", "もも", "もも", "のうち", "、", "とは", "平安", "時代に", "徳", "川", "家", "康", "が", "申し上げ", "た", "ものである", "といわれ", "ている", "。'

# %%
'", "'.join(tokenizer.tokenize("本記事では Google の T5(Text-to-Text Transfer Transformer) *1によるテキスト生成について、学習や推論のコード例と実験結果を交えてご紹介します。実験としては livedoor ニュースコーパス*2での文章分類、やさしい日本語コーパス*3及びやさしい日本語拡張コーパス*4を用いたやさしい日本語変換を行いました。"))
# Out:
# '▁", "本", "記事", "では", "▁Google", "▁", "の", "▁T", "5", "(", "Text", "-", "to", "-", "Text", "▁Transfer", "▁Transformer", ")", "▁", "*1", "による", "テキスト", "生成", "について", "、", "学習", "や", "推", "論", "の", "コード", "例", "と", "実験", "結果を", "交", "えて", "ご紹介します", "。", "実験", "としては", "▁live", "door", "▁", "ニュース", "コー", "パス", "*", "2", "での", "文章", "分類", "、", "やさしい", "日本語", "コー", "パス", "*", "3", "及び", "やさしい", "日本語", "拡張", "コー", "パス", "*", "4", "を用いた", "やさしい", "日本語", "変換", "を行いました", "。'

# %% [markdown]
# ## mT5-largeの言語モデリングの性能をチェック

# %%
text = "安倍晋三は日本の <extra_id_0> だ。"
outputs = model.generate(tokenizer(text, return_tensors='pt').input_ids)
tokenizer.convert_ids_to_tokens(outputs.numpy().tolist()[0])
# Out:
# ['<pad>',
#  '▁<extra_id_0>',
#  '▁',
#  '総理',
#  '▁<extra_id_1>',
#  '▁',
#  '総理',
#  '▁<extra_id_2>',
#  '▁',
#  '総理',
#  '▁<extra_id_3>',
#  '▁',
#  '総理',
#  '▁<extra_id_4>',
#  '▁',
#  '総理',
#  '▁<extra_id_5>',
#  '▁',
#  '総理',
#  '▁<extra_id_6>']

# %%
text = "安倍晋三は日本の <extra_id_0> で、 <extra_id_1> と呼ばれる経済政策を打ち出し日本経済を大きく回復させた。"
outputs = model.generate(tokenizer(text, return_tensors='pt').input_ids)
tokenizer.convert_ids_to_tokens(outputs.numpy().tolist()[0])
# Out:
# ['<pad>',
#  '▁<extra_id_0>',
#  '▁',
#  '首相',
#  '▁<extra_id_1>',
#  '▁「',
#  'アベ',
#  'ノミ',
#  'クス',
#  '」',
#  '▁<extra_id_2>',
#  '▁',
#  '経済',
#  '政策',
#  'の',
#  '▁',
#  'リーダー',
#  '▁<extra_id_3>',
#  '▁',
#  '首相']

# %%
# ❌な例, wiki
text = " <extra_id_0>はグラフ理論における最短経路問題を解くための最良優先探索によるアルゴリズムである。"
outputs = model.generate(tokenizer(text, return_tensors='pt').input_ids)
tokenizer.convert_ids_to_tokens(outputs.numpy().tolist()[0])
# Out:
# ['<pad>',
#  '▁<extra_id_0>',
#  'である',
#  '。',
#  '▁',
#  '▁<extra_id_1>',
#  'ゴ',
#  'リズム',
#  '▁<extra_id_1>',
#  'ゴ',
#  'リズム',
#  '▁<extra_id_15>',
#  '知',
#  'られている',
#  '。',
#  '▁',
#  '最も',
#  '重要な',
#  '特徴',
#  'は']

# %%
# ⭕️な例, yahoo news
text = "売れっ子 <extra_id_0>だけに、豪邸で優雅な暮らしをしているのでは？　と思いきや、 <extra_id_1>を送っている。"
outputs = model.generate(tokenizer(text, return_tensors='pt').input_ids)
tokenizer.convert_ids_to_tokens(outputs.numpy().tolist()[0])
# Out:
# ['<pad>',
#  '▁<extra_id_0>',
#  '女優',
#  '▁<extra_id_1>',
#  '実際には',
#  '、',
#  '平凡',
#  'な',
#  '生活',
#  '▁<extra_id_2>',
#  '芸能人',
#  'は',
#  '、',
#  '平凡',
#  'な',
#  '生活',
#  '▁<extra_id_3>',
#  '女優',
#  'な',
#  '▁<extra_id_15>']

# %%
# ⭕️, 5ch
# "ｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗ ゴミゲーを１０円で買ったからって１０円の損失やってのｗオマエｗ分かってねえなｗｗｗｗｗ"
text = "ｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗｗ ゴミゲーを１０円で買った <extra_id_0>１０円の損失やってのｗ <extra_id_1>ｗ分かってねえな <extra_id_2>"
outputs = model.generate(tokenizer(text, return_tensors='pt').input_ids)
tokenizer.convert_ids_to_tokens(outputs.numpy().tolist()[0])
# Out:
# ['<pad>',
#  '▁<extra_id_0>',
#  'のに',
#  '▁<extra_id_1>',
#  '▁',
#  '何',
#  'やって',
#  'んの',
#  '▁<extra_id_2>',
#  'w',
#  '</s>']

# %%
# ⭕️, twitter
# "しやがれ中ずっと 泣くもんかって涙堪えてたんだけど、HELLO NEW DREAMのcm流れてダメだった。素敵なサプライズ....もう愛しかなくて....すごいよ嵐。スポンサーの皆さんありがとう号泣"
text = "しやがれ中ずっと 泣くもんかって涙堪えてたんだけど、HELLO NEW DREAMのcm流れて <extra_id_0>だった。素敵な <extra_id_1>もう愛しかなくて....すごいよ嵐。スポンサーの皆さん <extra_id_2>号泣"
outputs = model.generate(tokenizer(text, return_tensors='pt').input_ids)
tokenizer.convert_ids_to_tokens(outputs.numpy().tolist()[0])
# Out:
# ['<pad>',
#  '▁<extra_id_0>',
#  '、',
#  'もう',
#  '涙',
#  'が止ま',
#  'らない',
#  'くらい',
#  '▁<extra_id_1>',
#  '歌',
#  '声',
#  'で',
#  '▁<extra_id_2>',
#  'ありがとう',
#  '。',
#  '▁<extra_id_3>',
#  '、',
#  'もう',
#  '涙',
#  'が止ま']

# %% [markdown]
# # mT5でzero-shotなスペル修正を行う
# 検証すること
# 1. Recallの高いエラー検出ができたとして、「decodingの各ステップで編集距離による制約を満たす最も尤度の高いトークンを選択していく」ことでエラー修正ができそうかどうかを確認
# 2. mT5のdecoderを使ってスペルエラー検出ができそうかどうか

# %% [markdown]
# ## 1. エラー検出ができたとして、エラー修正ができそうかどうか

# %%
texts = [
    "彼はファヴローにクラッシック西部劇映画を提供した。", # 'クラッシック' → 'クラシック'
    "民主党の予備選挙ではヒラリー・クリントンが1位となり、バラク・オバマが僅差の2位だた。",  # 'だた' → 'だった'
    "クラゲには4つ放射管を持つが触手はもたない。",  # '' -> 'の'
    "桶狭間の戦いで国友制の鉄砲が織田信長により初めて戦力として使用された。",  # '制' → '製'
    "ひきこもりの更正をはじめたきっかけ",  # '正' → '生'
]

# %%
# 何かしらのエラー検出でマスクする
masked_texts = [
    "彼はファヴローに <extra_id_0>西部劇映画を提供した。", # 'クラッシック' → 'クラシック'
    "民主党の予備選挙ではヒラリー・クリントンが1位となり、バラク・オバマが僅差の2位 <extra_id_0>",  # 'だた' → 'だった'
    "クラゲには <extra_id_0>を持つが触手はもたない。",  # '' -> 'の'
    "桶狭間の戦いで <extra_id_0>の鉄砲が織田信長により初めて戦力として使用された。",  # '制' → '製'
    "ひきこもりの <extra_id_0>をはじめたきっかけ",  # '正' → '生'
]

# %%
batch = tokenizer.prepare_seq2seq_batch(src_texts=masked_texts, tgt_texts=['<pad> <extra_id_0>'] * 5, return_tensors="pt")
output_step1 = model(**batch)

# %%
output_step1 = model(**batch)

# %%
output_step1.logits.shape
# Out:
# torch.Size([5, 3, 250112])

# %%
top_logits, top_indices = output_step1.logits[:, -1].sort(dim=-1, descending=True)  # 末尾のトークンの次にくる単語の予測をスコアでソート

# %%
print(top_logits.shape, top_indices.shape)
# Out:
# torch.Size([5, 250112]) torch.Size([5, 250112])

# %%
top_tokens = [tokenizer.convert_ids_to_tokens(each_indices) for each_indices in top_indices.numpy().tolist()]

# %%
from spell_correction.utils import BeginningLevenshtein
beginning_levenshtein = BeginningLevenshtein()

# %%
import math
def sigmoid(x):
    return 1 / (1 + math.exp(-x))

# %% [markdown]
# ### 'クラッシック'に代わる尤もらしい単語
#
# 原文: 彼はファヴローにクラッシック西部劇映画を提供した。
#
# * 単純に尤度が高い単語を選ぶと、文意を損なう。
# * 尤度が高く、かつ'ク'から始まるトークンを選ぶとスペル修正に使えそう
#   * 厳密には'クラッシック'の冒頭部との編集距離が小さく、よりマッチしているトークン（詳細は後述）

# %%
original_token = 'クラッシック'
candidates = []
for rank, (token, logit, index) in enumerate(zip(top_tokens[0], top_logits[0], top_indices[0])):
    candidate = beginning_levenshtein(token, original_token)
    candidate['rank'] = rank
    candidate['token'] = token
    candidate['logit'] = logit.tolist()
    candidate['index'] = index.tolist()
    # より一致部分が多く、より似ていて、より尤度の高いトークンを選びたい多目的最適化のようなものだが、暫定的に適当なスコアを作って最大化で代用する
    candidate['match_score'] = candidate['match_len'] / (candidate['distance'] + 1) * sigmoid(candidate['logit'])
    candidates.append(candidate)

# %%
for c in candidates[:30]:
    print(c)
# Out:
# {'match_ref': '', 'match_len': 0, 'distance': 5.0, 'rank': 0, 'token': 'いくつかの', 'logit': 3.3284339904785156, 'index': 176894, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 2.0, 'rank': 1, 'token': '彼の', 'logit': 2.6667046546936035, 'index': 104567, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 3.0, 'rank': 2, 'token': '多くの', 'logit': 2.545552968978882, 'index': 36431, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 3, 'token': '、', 'logit': 1.5796977281570435, 'index': 292, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 3.0, 'rank': 4, 'token': '新しい', 'logit': 0.9527663588523865, 'index': 26634, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 3.0, 'rank': 5, 'token': '最初の', 'logit': 0.588798999786377, 'index': 100843, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 2.0, 'rank': 6, 'token': '最も', 'logit': 0.4598374366760254, 'index': 65454, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 3.0, 'rank': 7, 'token': '優れた', 'logit': 0.37967419624328613, 'index': 163464, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 3.0, 'rank': 8, 'token': '多数の', 'logit': 0.34895622730255127, 'index': 209087, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 2.0, 'rank': 9, 'token': 'この', 'logit': 0.3298776149749756, 'index': 3103, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 3.0, 'rank': 10, 'token': '続いて', 'logit': 0.21418654918670654, 'index': 151482, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 2.0, 'rank': 11, 'token': '監督', 'logit': 0.2126539945602417, 'index': 56678, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 4.0, 'rank': 12, 'token': 'すべての', 'logit': 0.19576489925384521, 'index': 65867, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 13, 'token': '▁', 'logit': 0.15808820724487305, 'index': 259, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 14, 'token': '3', 'logit': 0.05605340003967285, 'index': 328, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 15, 'token': '愛', 'logit': -0.009752988815307617, 'index': 14942, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 3.0, 'rank': 16, 'token': '非常に', 'logit': -0.05553913116455078, 'index': 50068, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 5.0, 'rank': 17, 'token': 'たくさんの', 'logit': -0.06211233139038086, 'index': 100578, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 3.0, 'rank': 18, 'token': '自身の', 'logit': -0.0844266414642334, 'index': 159284, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 2.0, 'rank': 19, 'token': '続く', 'logit': -0.10357427597045898, 'index': 119760, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 20, 'token': '彼', 'logit': -0.13210314512252808, 'index': 49035, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 2.0, 'rank': 21, 'token': '他の', 'logit': -0.19057166576385498, 'index': 28770, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 2.0, 'rank': 22, 'token': '彼は', 'logit': -0.20033693313598633, 'index': 106036, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 3.0, 'rank': 23, 'token': '初めて', 'logit': -0.24123215675354004, 'index': 48785, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 5.0, 'rank': 24, 'token': '素晴らしい', 'logit': -0.2587457299232483, 'index': 71651, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 2.0, 'rank': 25, 'token': '初の', 'logit': -0.3285808563232422, 'index': 131096, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 3.0, 'rank': 26, 'token': '最初に', 'logit': -0.3448500633239746, 'index': 123292, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 2.0, 'rank': 27, 'token': '彼が', 'logit': -0.3619709014892578, 'index': 178995, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 2.0, 'rank': 28, 'token': '映画', 'logit': -0.39579176902770996, 'index': 25875, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 2.0, 'rank': 29, 'token': '向け', 'logit': -0.4557521343231201, 'index': 48793, 'match_score': 0.0}

# %%
for c in sorted(candidates, key=lambda c: c['match_score'], reverse=True)[:30]:
    print(c)
# Out:
# {'match_ref': 'クラッシック', 'match_len': 6, 'distance': 1.0, 'rank': 569, 'token': 'クラシック', 'logit': -3.036130905151367, 'index': 119003, 'match_score': 0.1374600984655472}
# {'match_ref': 'クラ', 'match_len': 2, 'distance':

# {'match_ref': 'クラ', 'match_len': 2, 'distance': 6.0, 'rank': 722, 'token': 'オーストラリア', 'logit': -3.276153326034546, 'index': 175493, 'match_score': 0.01039954072779904}
# {'match_ref': 'クラ', 'match_len': 2, 'distance': 1.0, 'rank': 2244, 'token': 'トラ', 'logit': -4.643647193908691, 'index': 56376, 'match_score': 0.009530827534164635}
# {'match_ref': 'クラッシ', 'match_len': 4, 'distance': 4.0, 'rank': 1953, 'token': 'ファッション', 'logit': -4.449071407318115, 'index': 48804, 'match_score': 0.00924348239422027}
# {'match_ref': 'クラ', 'match_len': 2, 'distance': 1.0, 'rank': 2315, 'token': 'クラブ', 'logit': -4.685793876647949, 'index': 57546, 'match_score': 0.00914107769835171}
# {'match_ref': 'ク', 'match_len': 1, 'distance': 4.0, 'rank': 585, 'token': 'アクセント', 'logit': -3.0514042377471924, 'index': 220124, 'match_score': 0.009031377446871694}
# {'match_ref': 'クラッ', 'match_len': 3, 'distance': 3.0, 'rank': 2002, 'token': 'クレジット', 'logit': -4.475774765014648, 'index': 206965, 'match_score': 0.008439991669518202}
# {'match_ref': 'クラ', 'match_len': 2, 'distance': 2.0, 'rank': 1826, 'token': 'フライ', 'logit': -4.357816696166992, 'index': 118819, 'match_score': 0.008429592781092062}
# {'match_ref': 'クラッシ', 'match_len': 4, 'distance': 3.0, 'rank': 2472, 'token': 'フレッシュ', 'logit': -4.774426460266113, 'index': 214336, 'match_score': 0.008372238866793329}

# %%
# 別のスコア関数を試してみる (distanceにexpをかけることで、編集距離を重視)
# 2番目の候補が'ク'になっていていい感じ
original_token = 'クラッシック'
candidates = []
for rank, (token, logit, index) in enumerate(zip(top_tokens[0], top_logits[0], top_indices[0])):
    candidate = beginning_levenshtein(token, original_token)
    candidate['rank'] = rank
    candidate['token'] = token
    candidate['logit'] = logit.tolist()
    candidate['index'] = index.tolist()
    # より一致部分が多く、より似ていて、より尤度の高いトークンを選びたい多目的最適化のようなものだが、暫定的に適当なスコアを作って最大化で代用する
    candidate['match_score'] = candidate['match_len'] / math.exp(candidate['distance']) * sigmoid(candidate['logit'])
    candidates.append(candidate)
for c in sorted(candidates, key=lambda c: c['match_score'], reverse=True)[:30]:
    print(c)
# Out:
# {'match_ref': 'クラッシック', 'match_len': 6, 'distance': 1.0, 'rank': 569, 'token': 'クラシック', 'logit': -3.036130905151367, 'index': 119003, 'match_score': 0.10113748841375388}
# {'match_ref': 'ク', 'match_len': 1, 'distance': 0.0, 'rank': 758, 'token': 'ク', 'logit': -3.3221492767333984, 'index': 6662, 'match_score': 0.0348191060957602}
# {'match_ref': 'クラ', 'match_len': 2, 'distance': 3.0, 'rank': 103, 'token': 'フランス', 'logit': -1.4590768814086914, 'index': 75179, 'match_score': 0.01878053398537874}
# {'match_ref': 'ク', 'match_len': 1, 'distance': 1.0, 'rank': 703, 'token': 'クリ', 'logit': -3.253140926361084, 'index': 68250, 'match_score': 0.013690334116179878}
# {'match_ref': 'クラッ', 'match_len': 3, 'distance': 2.0, 'rank': 885, 'token': 'ブラック', 'logit': -3.479574203491211, 'index': 21545, 'match_score': 0.012139180102912022}
# {'match_ref': 'クラ', 'match_len': 2, 'distance': 2.0, 'rank': 634, 'token': 'ドラマ', 'logit': -3.1350512504577637, 'index': 53130, 'match_score': 0.011282728824212239}
# {'match_ref': 'クラ', 'match_len': 2, 'distance': 0.0, 'rank': 3179, 'token': 'クラ', 'logit': -5.190471649169922, 'index': 48440, 'match_score': 0.011077066418826642}
# {'match_ref': 'クラ', 'match_len': 2, 'distance': 1.0, 'rank': 1794, 'token': 'サラ', 'logit': -4.332617282867432, 'index': 152336, 'match_score': 0.009537558584747686}
# {'match_ref': 'クラ', 'match_len': 2, 'distance': 1.0, 'rank':
original_token = 'だた'
candidates = []
for rank, (token, logit, index) in enumerate(zip(top_tokens[0], top_logits[0], top_indices[0])):
    candidate = beginning_levenshtein(token, original_token)
    candidate['rank'] = rank
    candidate['token'] = token
    candidate['logit'] = logit.tolist()
    candidate['index'] = index.tolist()
    # より一致部分が多く、より似ていて、より尤度の高いトークンを選びたい多目的最適化のようなものだが、暫定的に適当なスコアを作って最大化で代用する
    candidate['match_score'] = candidate['match_len'] / (candidate['distance'] + 1) * sigmoid(candidate['logit'])
    candidates.append(candidate)
for c in sorted(candidates, key=lambda c: c['match_score'], reverse=True)[:30]:
    print(c)
# Out:
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 7, 'token': '優れた', 'logit': 0.37967419624328613, 'index': 163464, 'match_score': 0.39586301375129107}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 1.0, 'rank': 72, 'token': 'また', 'logit': -1.1446471214294434, 'index': 6134, 'match_score': 0.2414681659188452}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 3.0, 'rank': 42, 'token': 'あなたの', 'logit': -0.6287240982055664, 'index': 42283, 'match_score': 0.17389995046254675}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 3.0, 'rank': 43, 'token': '書かれた', 'logit': -0.6733708381652832, 'index': 234721, 'match_score': 0.1688712325681762}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 1.0, 'rank': 140, 'token': '似た', 'logit': -1.7438538074493408, 'index': 224733, 'match_score': 0.14882409064086052}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 80, 'token': '新たな', 'logit': -1.2902559041976929, 'index': 87989, 'match_score': 0.14387299968778164}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 100, 'token': '書いた', 'logit': -1.4306073188781738, 'index': 142012, 'match_score': 0.12866938303647807}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 3.0, 'rank': 126, 'token': '変わった', 'logit': -1.6335457563400269, 'index': 194024, 'match_score': 0.0816726034775062}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 3.0, 'rank': 137, 'token': '作られた', 'logit': -1.7363464832305908, 'index': 185311, 'match_score': 0.07488879693719616}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 214, 'token': '残った', 'logit': -2.139606237411499, 'index': 234698, 'match_score': 0.0702043219318636}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 275, 'token': 'された', 'logit': -2.345632314682007, 'index': 7351, 'match_score': 0.05827571069180752}
# {'match_ref': 'だ', 'match_len': 1, 'distance': 1.0, 'rank': 221, 'token': 'まだ', 'logit': -2.154733419418335, 'index': 27363, 'match_score': 0.05194486532603632}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 378, 'token': '言った', 'logit': -2.6393237113952637, 'index': 136218, 'match_score': 0.044433395809002726}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 403, 'token': '冷たい', 'logit': -2.68988037109375, 'index': 220867, 'match_score': 0.04238209310860905}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 3.0, 'rank': 306, 'token': '私たちの', 'logit': -2.448695182800293, 'index': 152818, 'match_score': 0.039767010159592955}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 443, 'token': '会った', 'logit': -2.7894296646118164, 'index': 214979, 'match_score': 0.03859870458291838}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 1.0, 'rank': 688, 'token': 'いた', 'logit': -3.2325279712677, 'index': 10963, 'match_score': 0.03795982050325104}
# {'match_ref': 'だ', 'match_len': 1, 'distance': 2.0, 'rank': 245, 'token': '選んだ', 'logit': -2.2473602294921875, 'index': 227802, 'match_score': 0.031859136477124544}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 578, 'token': 'あなた', 'logit': -3.046987533569336, 'index': 57995, 'match_score': 0.0302318057208127}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 641, 'token': '作った', 'logit': -3.1444778442382812, 'index': 148490, 'match_score': 0.027539612511294435}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 1.0, 'rank': 960, 'token': 'した', 'logit': -3.568343162536621, 'index': 2166, 'match_score': 0.02742897519480076}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 657, 'token': '驚いた', 'logit': -3.1678547859191895, 'index': 224109, 'match_score': 0.026928990638893882}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 1.0, 'rank': 997, 'token': '見た', 'logit': -3.6060240268707275, 'index': 113704, 'match_score': 0.026441477938503294}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 683, 'token': 'たった', 'logit': -3.218390703201294, 'index': 132346, 'match_score': 0.02565298891276072}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 3.0, 'rank': 510, 'token': 'かかった', 'logit': -2.9250292778015137, 'index': 206969, 'match_score': 0.0254650275285599}
# {'match_ref': 'だ', 'match_len': 1, 'distance': 1.0, 'rank': 522, 'token': 'だけ', 'logit': -2.9464244842529297, 'index': 13386, 'match_score': 0.024952886364636807}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 3.0, 'rank': 523, 'token': '始まった', 'logit': -2.949230194091797, 'index': 217715, 'match_score': 0.02488645367391788}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 3.0, 'rank': 609, 'token': 'なかった', 'logit': -3.093761920928955, 'index': 23924, 'match_score': 0.021682652112201134}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 831, 'token': 'かけた', 'logit': -3.406111478805542, 'index': 193723, 'match_score': 0.02140334058953328}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 3.0, 'rank': 701, 'token': 'まったく', 'logit': -3.249727964401245, 'index': 121200, 'match_score': 0.01866833189523153}

# %%
# 別のスコア関数を試してみる (distanceにexpをかけることで、編集距離を重視)
# "民主党の予備選挙ではヒラリー・クリントンが1位となり、バラク・オバマが僅差の2位 <extra_id_0>",  # 'だた' → 'だった'
original_token = 'だた'
candidates = []
for rank, (token, logit, index) in enumerate(zip(top_tokens[0], top_logits[0], top_indices[0])):
    candidate = beginning_levenshtein(token, original_token)
    candidate['rank'] = rank
    candidate['token'] = token
    candidate['logit'] = logit.tolist()
    candidate['index'] = index.tolist()
    # より一致部分が多く、より似ていて、より尤度の高いトークンを選びたい多目的最適化のようなものだが、暫定的に適当なスコアを作って最大化で代用する
    candidate['match_score'] = candidate['match_len'] / math.exp(candidate['distance']) * sigmoid(candidate['logit'])
    candidates.append(candidate)
for c in sorted(candidates, key=lambda c: c['match_score'], reverse=True)[:30]:
    print(c)
# Out:
# {'match_ref': 'だた', 'match_len': 2, 'distance': 1.0, 'rank': 72, 'token': 'また', 'logit': -1.1446471214294434, 'index': 6134, 'match_score': 0.17766234787783577}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 7, 'token': '優れた', 'logit': 0.37967419624328613, 'index': 163464, 'match_score': 0.16072269926679025}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 1.0, 'rank': 140, 'token': '似た', 'logit': -1.7438538074493408, 'index': 224733, 'match_score': 0.1094986465956157}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 80, 'token': '新たな', 'logit': -1.2902559041976929, 'index': 87989, 'match_score': 0.05841327948854106}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 100, 'token': '書いた', 'logit': -1.4306073188781738, 'index': 142012, 'match_score': 0.052240522191365914}
# {'match_ref': 'だ', 'match_len': 1, 'distance': 1.0, 'rank': 221, 'token': 'まだ', 'logit': -2.154733419418335, 'index': 27363, 'match_score': 0.03821889605573615}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 3.0, 'rank': 42, 'token': 'あなたの', 'logit': -0.6287240982055664, 'index': 42283, 'match_score': 0.03463187489138787}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 3.0, 'rank': 43, 'token': '書かれた', 'logit': -0.6733708381652832, 'index': 234721, 'match_score': 0.03363041440494897}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 214, 'token': '残った', 'logit': -2.139606237411499, 'index': 234698, 'match_score': 0.02850336537924931}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 1.0, 'rank': 688, 'token': 'いた', 'logit': -3.2325279712677, 'index': 10963, 'match_score': 0.027929275107408506}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 275, 'token': 'された', 'logit': -2.345632314682007, 'index': 7351, 'match_score': 0.023660279436872014}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 1.0, 'rank': 960, 'token': 'した', 'logit': -3.568343162536621, 'index': 2166, 'match_score': 0.020181112133137315}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 1.0, 'rank': 997, 'token': '見た', 'logit': -3.6060240268707275, 'index': 113704, 'match_score': 0.019454552255527224}
# {'match_ref': 'だ', 'match_len': 1, 'distance': 1.0, 'rank': 522, 'token': 'だけ', 'logit': -2.9464244842529297, 'index': 13386, 'match_score': 0.018359307782874184}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 378, 'token': '言った', 'logit': -2.6393237113952637, 'index': 136218, 'match_score': 0.018040218620927712}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 403, 'token': '冷たい', 'logit': -2.68988037109375, 'index': 220867, 'match_score': 0.01720737772504229}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 3.0, 'rank': 126, 'token': '変わった', 'logit': -1.6335457563400269, 'index': 194024, 'match_score': 0.016264957972464175}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 443, 'token': '会った', 'logit': -2.7894296646118164, 'index': 214979, 'match_score': 0.0156712998518868}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 3.0, 'rank': 137, 'token': '作られた', 'logit': -1.7363464832305908, 'index': 185311, 'match_score': 0.014913974612397062}
# {'match_ref': 'だ', 'match_len': 1, 'distance': 2.0, 'rank': 245, 'token': '選んだ', 'logit': -2.2473602294921875, 'index': 227802, 'match_score': 0.01293499577641665}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 578, 'token': 'あなた', 'logit': -3.046987533569336, 'index': 57995, 'match_score': 0.012274289969941305}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 1.0, 'rank': 1580, 'token': '出た', 'logit': -4.168867588043213, 'index': 180922, 'match_score': 0.011208624651254724}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 641, 'token': '作った', 'logit': -3.1444778442382812, 'index': 148490, 'match_score': 0.011181243778327786}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 657, 'token': '驚いた', 'logit': -3.1678547859191895, 'index': 224109, 'match_score': 0.010933327726172387}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 683, 'token': 'たった', 'logit': -3.218390703201294, 'index': 132346, 'match_score': 0.010415263561122472}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 831, 'token': 'かけた', 'logit': -3.406111478805542, 'index': 193723, 'match_score': 0.008689881482682528}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 3.0, 'rank': 306, 'token': '私たちの', 'logit': -2.448695182800293, 'index': 152818, 'match_score': 0.007919531414404778}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 1.0, 'rank': 2130, 'token': 'きた', 'logit': -4.564662933349609, 'index': 50354, 'match_score': 0.00758278073082549}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 956, 'token': '付いた', 'logit': -3.563596248626709, 'index': 217410, 'match_score': 0.007458568710832565}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 2.0, 'rank': 968, 'token': 'または', 'logit': -3.574742078781128, 'index': 30373, 'match_score': 0.0073781518357185875}

# %%
# 別のスコア関数を試してみる (distanceにexpをかけることで、編集距離を重視)
# "民主党の予備選挙ではヒラリー・クリントンが1位となり、バラク・オバマが僅差の2位 <extra_id_0>",  # 'だた' → 'だった'
original_token = 'だた'
candidates = []
for rank, (token, logit, index) in enumerate(zip(top_tokens[0], top_logits[0], top_indices[0])):
    candidate = beginning_levenshtein(token, original_token)
    candidate['rank'] = rank
    candidate['token'] = token
    candidate['logit'] = logit.tolist()
    candidate['index'] = index.tolist()
    # より一致部分が多く、より似ていて、より尤度の高いトークンを選びたい多目的最適化のようなものだが、暫定的に適当なスコアを作って最大化で代用する
    candidate['match_score'] = candidate['match_len'] / math.exp(candidate['distance']) * sigmoid(candidate['logit'])
    candidates.append(candidate)

# %%
for c in sorted(filter(lambda c: c['distance'] <= 1, candidates), key=lambda c: c['match_score'], reverse=True)[:100]:
    print(c)
# Out:
# {'match_ref': 'だた', 'match_len': 2, 'distance': 1.0, 'rank': 72, 'token': 'また', 'logit': -1.1446471214294434, 'index': 6134, 'match_score': 0.17766234787783577}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 1.0, 'rank': 140, 'token': '似た', 'logit': -1.7438538074493408, 'index': 224733, 'match_score': 0.1094986465956157}
# {'match_ref': 'だ', 'match_len': 1, 'distance': 1.0, 'rank': 221, 'token': 'まだ', 'logit': -2.154733419418335, 'index': 27363, 'match_score': 0.03821889605573615}
# {'match_ref': 'だた', 'match_len': 2, 'distance': 1.0, 'rank':
 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 55, 'token': '同', 'logit': -0.8711784482002258, 'index': 5111, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 61, 'token': '数', 'logit': -0.936435341835022, 'index': 4890, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 81, 'token': '大', 'logit': -1.3024152517318726, 'index': 1146, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 84, 'token': '向', 'logit': -1.357886791229248, 'index': 5836, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 86, 'token': '他', 'logit': -1.3677986860275269, 'index': 3763, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 89, 'token': '襲', 'logit': -1.373114824295044, 'index': 119668, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 92, 'token': 'ス', 'logit': -1.3912512063980103, 'index': 3144, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 93, 'token': '三', 'logit': -1.3926200866699219, 'index': 2092, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 94, 'token': '作', 'logit': -1.4109092950820923, 'index': 7249, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 97, 'token': '忠', 'logit': -1.4187633991241455, 'index': 45606, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 98, 'token': '捧', 'logit': -1.4205574989318848, 'index': 177222, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 101, 'token': '北', 'logit': -1.4327311515808105, 'index': 7246, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 105, 'token': '属', 'logit': -1.5022355318069458, 'index': 31725, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 107, 'token': '賛', 'logit': -1.520745038986206, 'index': 97803, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 108, 'token': '対', 'logit': -1.5236495733261108, 'index': 28408, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 112, 'token': '8', 'logit': -1.5695643424987793, 'index': 449, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 115, 'token': '熱', 'logit': -1.581133484840393, 'index': 15862, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 117, 'token': '力', 'logit': -1.5861300230026245, 'index': 3862, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 118, 'token': 'と', 'logit': -1.5872092247009277, 'index': 725, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 121, 'token': '代', 'logit': -1.6135590076446533, 'index': 5969, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 125, 'token': '新', 'logit': -1.6310744285583496, 'index': 2188, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 132, 'token': 'ア', 'logit': -1.6771619319915771, 'index': 5832, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 133, 'token': '6', 'logit': -1.6918315887451172, 'index': 451, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 141, 'token': '配', 'logit': -1.7508363723754883, 'index': 13983, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 144, 'token': '単', 'logit': -1.7743690013885498, 'index': 60793, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 145, 'token': '初', 'logit': -1.7822067737579346, 'index': 12869, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 150, 'token': '多', 'logit': -1.8203456401824951, 'index': 3139, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 154, 'token': '最', 'logit': -1.8404816389083862, 'index': 5507, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 155, 'token': '米', 'logit': -1.8414247035980225, 'index': 6587, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 156, 'token': '近', 'logit': -1.8469104766845703, 'index': 8659, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 159, 'token': '抗', 'logit': -1.8562744855880737, 'index': 24094, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 161, 'token': '殺', 'logit': -1.8593335151672363, 'index': 47046, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 166, 'token': 'シ', 'logit': -1.9164992570877075, 'index': 7675, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 168, 'token': 'バ', 'logit': -1.9214249849319458, 'index': 9314, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 169, 'token': 'オ', 'logit': -1.9217268228530884, 'index': 9369, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 170, 'token': '沿', 'logit': -1.9321231842041016, 'index': 54619, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 173, 'token': 'エ', 'logit': -1.9390029907226562, 'index': 8918, 'match_score': 0.0}
# {'match_ref': '', 'match_len': 0, 'distance': 1.0, 'rank': 177, 'token': '特', 'logit': -1.9673943519592285, 'index': 4805, 'match_score': 0.0}

# %%
# "クラゲには <extra_id_0>を持つが触手はもたない。"
# '' -> 'の'
original_token = '4つ放射管'
candidates = []
for rank, (token, logit, index) in enumerate(zip(top_tokens[2], top_logits[2], top_indices[2])):
    candidate = beginning_levenshtein(token, original_token)
    candidate['rank'] = rank
    candidate['token'] = token
    candidate['logit'] = logit.tolist()
    candidate['index'] = index.tolist()
    # より一致部分が多く、より似ていて、より尤度の高いトークンを選びたい多目的最適化のようなものだが、暫定的に適当なスコアを作って最大化で代用する
    candidate['match_score'] = candidate['match_len'] / (candidate['distance'] + 1) * sigmoid(candidate['logit'])
    candidates.append(candidate)
for c in sorted(candidates, key=lambda c: c['match_score'], reverse=True)[:30]:
    print(c)
# Out:
# {'match_ref': '4', 'match_len': 1, 'distance': 0.0, 'rank': 263, 'token': '4', 'logit': -2.3533935546875, 'index': 410, 'match_score': 0.08679641236419319}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 2.0, 'rank': 195, 'token': '二つの', 'logit': -2.083512544631958, 'index': 228290, 'match_score': 0.07380644856269011}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 1.0, 'rank': 387, 'token': 'まつ', 'logit': -2.7072627544403076, 'index': 165235, 'match_score': 0.06254615535134471}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 3.0, 'rank': 271, 'token': 'いくつか', 'logit': -2.3756659030914307, 'index': 153442, 'match_score': 0.042523606990237}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 1.0, 'rank': 630, 'token': '一つ', 'logit': -3.158996343612671, 'index': 87573, 'match_score': 0.04073825703582776}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 4.0, 'rank': 259, 'token': 'いくつかの', 'logit': -2.3410849571228027, 'index': 176894, 'match_score': 0.035110800425335466}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 1.0, 'rank': 961, 'token': 'もつ', 'logit': -3.5992894172668457, 'index': 221446, 'match_score': 0.02661539646479209}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 1.0, 'rank': 1121, 'token': '持つ', 'logit': -3.820922374725342, 'index': 148329, 'match_score': 0.021437931277417718}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 1.0, 'rank': 1187, 'token': 'かつ', 'logit': -3.8931944370269775, 'index': 58257, 'match_score': 0.019973084634491357}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 1.0, 'rank': 1266, 'token': 'つつ', 'logit': -3.9804060459136963, 'index': 116676, 'match_score': 0.01833558069055815}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 1.0, 'rank': 1268, 'token': '二つ', 'logit': -3.9824087619781494, 'index': 196138, 'match_score': 0.0182995677801452}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 2.0, 'rank': 1406, 'token': '一つの', 'logit': -4.107458114624023, 'index': 158629, 'match_score': 0.01078888405553757}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 1.0, 'rank': 1933, 'token': '立つ', 'logit': -4.5276384353637695, 'index': 198057, 'match_score': 0.010690640590948399}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 2.0, 'rank': 1592, 'token': 'ひとつ', 'logit': -4.2650628089904785, 'index': 117553, 'match_score': 0.009237526706169438}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 3.0, 'rank': 1563, 'token': 'もう一つ', 'logit': -4.2456769943237305, 'index': 197756, 'match_score': 0.007061847623277769}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 1.0, 'rank': 2900, 'token': 'ぶつ', 'logit': -5.129755020141602, 'index': 201210, 'match_score': 0.0058831932921243855}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 2.0, 'rank': 2288, 'token': 'いつも', 'logit': -4.7686333656311035, 'index': 35265, 'match_score': 0.005613647472335432}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 1.0, 'rank': 3079, 'token': 'うつ', 'logit': -5.232636451721191, 'index': 156435, 'match_score': 0.005311071488954821}
# {'match_ref': '4', 'match_len': 1, 'distance': 1.0, 'rank': 2119, 'token': '14', 'logit': -4.657462120056152, 'index': 1635, 'match_score': 0.00470064725350622}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 2.0, 'rank': 2798, 'token': 'かつて', 'logit': -5.077658176422119, 'index': 130267, 'match_score': 0.004130575966633986}
# {'match_ref': '4', 'match_len': 1, 'distance': 1.0, 'rank': 2357, 'token': '、4', 'logit': -4.816971778869629, 'index': 140616, 'match_score': 0.004013154642976263}
# {'match_ref': '4', 'match_len': 1, 'distance': 1.0, 'rank': 2693, 'token': '24', 'logit': -5.018725872039795, 'index': 1455, 'match_score': 0.0032847516534484423}
# {'match_ref': '4', 'match_len': 1, 'distance': 1.0, 'rank': 2842, 'token': '▁4', 'logit': -5.100762367248535, 'index': 419, 'match_score': 0.0030276057105534304}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 2.0, 'rank': 4041, 'token': 'おやつ', 'logit': -5.731054782867432, 'index': 224307, 'match_score': 0.0021554445354335944}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 3.0, 'rank': 3528, 'token': '少しずつ', 'logit': -5.458204746246338, 'index': 171871, 'match_score': 0.0021215590228577733}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 3.0, 'rank': 3551, 'token': 'いつでも', 'logit': -5.468172550201416, 'index': 119491, 'match_score': 0.002100605187981032}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 3.0, 'rank': 3765, 'token': 'ひとつの', 'logit': -5.589761734008789, 'index': 232490, 'match_score': 0.0018610063833553129}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 1.0, 'rank': 5307, 'token': 'やつ', 'logit': -6.292331218719482, 'index': 114380, 'match_score': 0.0018470233238247495}
# {'match_ref': '4', 'match_len': 1, 'distance': 1.0, 'rank': 3788, 'token': '40', 'logit': -5.605727195739746, 'index': 2334, 'match_score': 0.001831638459848485}
# {'match_ref': '4つ', 'match_len': 2, 'distance': 2.0, 'rank': 4414, 'token': '目立つ', 'logit': -5.906761646270752, 'index': 204711, 'match_score': 0.001809066987101732}

# %%
#  "桶狭間の戦いで国友制の鉄砲が織田信長により初めて戦力として使用された。"
# 桶狭間の戦いで <extra_id_0>の鉄砲が織田信長により初めて戦力として使用された。"
# '制' → '製'
original_token = '国友制'
candidates = []
for rank, (token, logit, index) in enumerate(zip(top_tokens[3], top_logits[3], top_indices[3])):
    candidate = beginning_levenshtein(token, original_token)
    candidate['rank'] = rank
    candidate['token'] = token
    candidate['logit'] = logit.tolist()
    candidate['index'] = index.tolist()
    # より一致部分が多く、より似ていて、より尤度の高いトークンを選びたい多目的最適化のようなものだが、暫定的に適当なスコアを作って最大化で代用する
    candidate['match_score'] = candidate['match_len'] / (candidate['distance'] + 1) * sigmoid(candidate['logit'])
    candidates.append(candidate)
for c in sorted(candidates, key=lambda c: c['match_score'], reverse=True)[:30]:
    print(c)
# Out:
# {'match_ref': '国', 'match_len': 1, 'distance': 1.0, 'rank': 103, 'token': '中国', 'logit': -3.304124355316162, 'index': 3161, 'match_score': 0.017714985167892324}
# {'match_ref': '国', 'match_len': 1, 'distance': 1.0, 'rank': 296, 'token': '我国', 'logit': -4.302565574645996, 'index': 44635, 'match_score': 0.006676537367965645}
# {'match_ref': '国', 'match_len': 1, 'distance': 1.0, 'rank': 322, 'token': '英国', 'logit': -4.3750386238098145, 'index': 41573, 'match_score': 0.006215588336775192}
# {'match_ref': '国', 'match_len': 1, 'distance': 0.0, 'rank': 617, 'token': '国', 'logit': -5.123970985412598, 'index': 3802, 'match_score': 0.005917118553079561}
# {'match_ref': '国', 'match_len': 1, 'distance': 1.0, 'rank': 622, 'token': '四国', 'logit': -5.126492023468018, 'index': 159421, 'match_score': 0.002951153997625095}
# {'match_ref': '国', 'match_len': 1, 'distance': 2.0, 'rank': 431, 'token': '中国の', 'logit': -4.740740776062012, 'index': 176582, 'match_score': 0.0028855281303586445}
# {'match_ref': '国', 'match_len': 1, 'distance': 1.0, 'rank': 698, 'token': '外国', 'logit': -5.241372585296631, 'index': 84093, 'match_score': 0.0026325592844325327}
# {'match_ref': '国', 'match_len': 1, 'distance': 1.0, 'rank':

# {'match_ref': '国', 'match_len': 1, 'distance': 1.0, 'rank': 6300, 'token': '国際', 'logit': -8.320533752441406, 'index': 46988, 'match_score': 0.00012170330891262222}
# {'match_ref': '国', 'match_len': 1, 'distance': 1.0, 'rank': 6463, 'token': '国防', 'logit': -8.365776062011719, 'index': 147098, 'match_score': 0.00011632112043466333}

# %%
# "ひきこもりの <extra_id_0>をはじめたきっかけ",  # '正' → '生'
original_token = '更正'
candidates = []
for rank, (token, logit, index) in enumerate(zip(top_tokens[4], top_logits[4], top_indices[4])):
    candidate = beginning_levenshtein(token, original_token)
    candidate['rank'] = rank
    candidate['token'] = token
    candidate['logit'] = logit.tolist()
    candidate['index'] = index.tolist()
    # より一致部分が多く、より似ていて、より尤度の高いトークンを選びたい多目的最適化のようなものだが、暫定的に適当なスコアを作って最大化で代用する
    candidate['match_score'] = candidate['match_len'] / (candidate['distance'] + 1) * sigmoid(candidate['logit'])
    candidates.append(candidate)
for c in sorted(candidates, key=lambda c: c['match_score'], reverse=True)[:30]:
    print(c)
# Out:
# {'match_ref': '更', 'match_len': 1, 'distance': 0.0, 'rank': 2436, 'token': '更', 'logit': -4.3974151611328125, 'index': 9411, 'match_score': 0.012159443894496878}
# {'match_ref': '更', 'match_len': 1, 'distance': 1.0, 'rank': 1639, 'token': '更新', 'logit': -3.7998902797698975, 'index': 16449, 'match_score': 0.010941809672227546}
# {'match_ref': '更正', 'match_len': 2, 'distance': 1.0, 'rank': 2827, 'token': '矯正', 'logit': -4.664065361022949, 'index': 190284, 'match_score': 0.00933999791265149}
# {'match_ref': '更正', 'match_len': 2, 'distance': 1.0, 'rank': 5894, 'token': '修正', 'logit': -6.107279300689697, 'index': 88101, 'match_score': 0.0022216537544695702}
# {'match_ref': '更正', 'match_len': 2, 'distance': 1.0, 'rank': 7644, 'token': '大正', 'logit': -6.761699676513672, 'index': 213565, 'match_score': 0.001155922828935303}
# {'match_ref': '更正', 'match_len': 2, 'distance': 1.0, 'rank': 8000, 'token': '適正', 'logit': -6.863402843475342, 'index': 176439, 'match_score': 0.0010442590916993914}
# {'match_ref': '更正', 'match_len': 2, 'distance': 1.0, 'rank': 8180, 'token': '改正', 'logit': -6.915980339050293, 'index': 108389, 'match_score': 0.0009908259634049013}
# {'match_ref': '更正', 'match_len': 2, 'distance': 1.0, 'rank': 9497, 'token': '補正', 'logit': -7.305246353149414, 'index': 182192, 'match_score': 0.0006715526547851037}
# {'match_ref': '更正', 'match_len': 2, 'distance': 1.0, 'rank': 11221, 'token': '真正', 'logit': -7.74269962310791, 'index': 81217, 'match_score': 0.00043371044340144373}
# {'match_ref': '更', 'match_len': 1, 'distance': 1.0, 'rank': 9020, 'token': '更に', 'logit': -7.177640438079834, 'index': 91676, 'match_score': 0.00038144236455915615}
# {'match_ref': '更正', 'match_len': 2, 'distance': 1.0, 'rank': 13095, 'token': '不正', 'logit': -8.143704414367676, 'index': 167837, 'match_score': 0.00029047445183932316}
# {'match_ref': '更正', 'match_len': 2, 'distance': 2.0, 'rank': 12289, 'token': '無修正', 'logit': -7.973349571228027, 'index': 209103, 'match_score': 0.00022960292752670602}
# {'match_ref': '更', 'match_len': 1, 'distance': 2.0, 'rank': 14218, 'token': '更新日', 'logit': -8.345163345336914, 'index': 194779, 'match_score': 7.916208104697463e-05}
# {'match_ref': '更', 'match_len': 1, 'distance': 1.0, 'rank': 18275, 'token': '更加', 'logit': -8.948321342468262, 'index': 56424, 'match_score': 6.496912053044277e-05}
# {'match_ref': '更', 'match_len': 1, 'distance': 1.0, 'rank': 32653, 'token': '変更', 'logit': -10.17483901977539, 'index': 44744, 'match_score': 1.9057986278320272e-05}
# {'match_ref': '更正', 'match_len': 2, 'distance': 1.0, 'rank': 52914, 'token': '公正', 'logit': -11.12048625946045, 'index': 158903, 'match_score': 1.4805659298819703e-05}
# {'match_ref': '更', 'match_len': 1, 'distance': 2.0, 'rank': 33147, 'token': 'を更新', 'logit': -10.203904151916504, 'index': 210459, 'match_score': 1.2341370730578377e-05}
# {'match_ref': '更正', 'match_len': 2, 'distance': 1.0, 'rank': 71765, 'token': '純正', 'logit': -11.720834732055664, 'index': 74280, 'match_score': 8.122741360206285e-06}
# {'match_ref': '更', 'match_len': 1, 'distance': 1.0, 'rank': 54813, 'token': '更多', 'logit': -11.187963485717773, 'index': 35353, 'match_score': 6.91979435707329e-06}
# {'match_ref': '更', 'match_len': 1, 'distance': 1.0, 'rank': 59137, 'token': '更大', 'logit': -11.332348823547363, 'index': 193478, 'match_score': 5.989467888341301e-06}
# {'match_ref': '更正', 'match_len': 2, 'distance': 2.0, 'rank': 70102, 'token': '真正的', 'logit': -11.673317909240723, 'index': 141508, 'match_score': 5.6786811993271305e-06}
# {'match_ref': '更', 'match_len': 1, 'distance': 1.0, 'rank': 64113, 'token': '更有', 'logit': -11.493721008300781, 'index': 184355, 'match_score': 5.096898284758524e-06}
# {'match_ref': '更', 'match_len': 1, 'distance': 2.0, 'rank': 63233, 'token': '更好的', 'logit': -11.466573715209961, 'index': 179544, 'match_score': 3.4914393755492885e-06}
# {'match_ref': '更正', 'match_len': 2, 'distance': 4.0, 'rank': 72032, 'token': '国内正規品', 'logit': -11.727710723876953, 'index': 235115, 'match_score': 3.226832594130981e-06}
# {'match_ref': '更', 'match_len': 1, 'distance': 2.0, 'rank': 91065, 'token': 'に変更', 'logit': -12.219157218933105, 'index': 177264, 'match_score': 1.6449929777643276e-06}
# {'match_ref': '更', 'match_len': 1, 'distance': 2.0, 'rank': 101074, 'token': '更好地', 'logit': -12.459918022155762, 'index': 210586, 'match_score': 1.2930145699932765e-06}
# {'match_ref': '更', 'match_len': 1, 'distance': 1.0, 'rank': 138704, 'token': '更好', 'logit': -13.288084983825684, 'index': 163542, 'match_score': 8.472806434777549e-07}
# {'match_ref': '更', 'match_len': 1, 'distance': 1.0, 'rank': 144448, 'token': '更为', 'logit': -13.410995483398438, 'index': 192613, 'match_score': 7.492866903347244e-07}
# {'match_ref': '更', 'match_len': 1, 'distance': 2.0, 'rank': 141985, 'token': 'の変更', 'logit': -13.35883903503418, 'index': 187612, 'match_score': 5.26269234493556e-07}
# {'match_ref': '更', 'match_len': 1, 'distance': 2.0, 'rank': 142419, 'token': '更多的', 'logit': -13.3681640625, 'index': 111234, 'match_score': 5.213845772807271e-07}

# %% [markdown]
# # Idea Memo
#
# 検出ができなくても、テキストを10分割くらいにして、各セグメントをマスクして直すということを10回やればいいや！！ ！
# 以内稲井
# つまり、「編集距離を一定以下に保ったまま、refinement（マスクして、尤度を高くする）をし続ける」
#
# スペル修正というタスクを、
#
# * 目的関数：尤度の最大化
# * 拘束条件: 編集距離の差が一定値以内 など
#
# というタスクに置き換える！
#
# 拘束条件は言語や状況によって変えてもいい
# * 読み/拼音の近さ
# * 文字の視覚的な類似度
#   * 実装としては「Visual Edit Distance」的な感じ。編集距離の各編集に重み付けをする
#     * l -> I のコストは0.1
#     * l -> A のコストは1.0
#     * l -> φ (削除)のコストは1.0
#     * . -> φ (削除)のコストは0.5
#
# 拘束条件を、編集距離の重みで表現したらスマートな実装になりそう

# %% [markdown]
# ## やってみた感想
# * ただ単純にマスクして予測させて、編集距離で拘束条件づけるだけだと、モデルが修正前の単語を知らないから候補が絞りきれない
#   * 更正 を 更生 に直したいが、更新などが候補として上がってきてしまう。
#     * これとかなら尤度で弾きうるが、国友制〜 → 国友製〜 が　中国制の~ とかになってしまいうる。
# * マスクすると修正前の単語の情報が伝わらないのでなんか別の方法を考える

# %%
text = "民主党の予備選挙ではヒラリー・クリントンが1位となり、バラク・オバマが僅差の2位 <extra_id_0> (だた)"
outputs = model.generate(tokenizer(text, return_tensors='pt').input_ids)
tokenizer.convert_ids_to_tokens(outputs.numpy().tolist()[0])
# Out:
# ['<pad>',
#  '▁<extra_id_0>',
#  'となりました',
#  '。',
#  '▁<extra_id_1>',
#  'となりました',
#  '。',
#  '▁',
#  '-',
#  '▁',
#  'だ',
#  'た',
#  '▁<extra_id_15>',
#  'となりました',
#  '。',
#  '▁',
#  '-',
#  '▁',
#  'だ',
#  'た']

# %%
batch = tokenizer.prepare_seq2seq_batch(src_texts=["民主党の予備選挙ではヒラリー・クリントンが1位となり、バラク・オバマが僅差の2位 <extra_id_0>"], tgt_texts=['<pad> <extra_id_0>だ'], return_tensors="pt")

# %%
output_step1 = model(**batch)

# %%
top_logits, top_indices = output_step1.logits[:, -1].sort(dim=-1, descending=True)  # 末尾のトークンの次にくる単語の予測をスコアでソート
top_tokens = [tokenizer.convert_ids_to_tokens(each_indices) for each_indices in top_indices.numpy().tolist()]

# %%
top_tokens[:10]
# Out:
# [['。',
#   '。(',
#   'と言われています',
#   '...',
#   'っています',
#   '。。',
#   '。【',
#   'そうだ',
#   '」',
#   '。■',
#   '。”',
#   '▁',
#   '。[',
#   '、',
#   '。※',
#   'そう',
#   '!',
#   '.',
#   'と思っています',
#   '。」',
#   '▁→',
#   '。・',
#   '▁■',
#   'と言われ',
#   '......',
#   '(',
#   'となりました',
#   '。「',
#   'といいます',
#   '・・・',
#   'しています',
#   'た',
#   'そうです',
#   '៕',
#   'しました',
#   '▁...',
#   '▁<extra_id_1>',
#   'といわれ',
#   'っている',
#   '...。',
#   '。●',
#   '】',
#   '”',
#   '・・・。',
#   'ということです',
#   'だ',
#   '</s>',
#   'と言えます',
#   'と感じました',
#   '....',
#   'となっています',
#   'として',
#   'そうで',
#   'という',
#   'っ',
#   '・・',
#   '〕',
#   'と言う',
#   'した',
#   '■',
#   '】【。】',
#   '¡£',
#   '・・。',
#   '▁<extra_id_56>',
#   '[/',
#   'といえる',
#   'ました',
#   'と言って',
#   '▼',
#   'と思われます',
#   '"',
#   '。1',
#   'と言った',
#   'と言われている',
#   '▁<extra_id_18>',
#   '</',
#   'とした',
#   'となります',
#   'となった',
#   'る',
#   '▁>>',
#   '\u202c',
#   'でした',
#   'と思いました',
#   '!!',
#   '」(',
#   'のです',
#   'と思われ',
#   'まし',
#   'と思っている',
#   'と言われて',
#   '【',
#   '」。',
#   '▁[...]',
#   ')',
#   'していました',
#   '.....',
#   '▁៕',
#   'ま',
#   '▁↑',
#   '[',
#   'と考えています',
#   '”。',
#   'ます',
#   'します',
#   ')。',
#   '――',
#   '\u202a.\u202c\u202c',
#   'を発表',
#   '※',
#   'えます',
#   'と言われた',
#   '▁|',
#   'と言います',
#   '▁【',
#   'など',
#   '▁←',
#   'べ',
#   '▁>',
#   'ってしまいます',
#   'った',
#   '▁Tweet',
#   '(*',
#   'www',
#   'としても',
#   'ー',
#   'つ',
#   'というのが',
#   '&#',
#   '▁(',
#   '―',
#   '。2019',
#   '。“',
#   '。《',
#   '▁▼',
#   '=',
#   '。2017',
#   '。。。',
#   'というふうに',
#   'ていました',
#   'となっている',
#   'なんて',
#   'されました',
#   '▁●',
#   '*',
#   'ています',
#   '▁©',
#   '▁[',
#   ',',
#   '......。',
#   'と思われる',
#   '▁<extra_id_35>',
#   '|',
#   '>>',
#   'と思った',
#   '.........',
#   'といった',
#   '→',
#   '.[',
#   '\\',
#   'と言える',
#   '・・・・',
#   'りました',
#   '発表',
#   'ぞ',
#   'といっても',
#   '▁(...)',
#   '▁^',
#   'に',
#   '★',
#   ']',
#   '。2',
#   '・・・・・',
#   'っていました',
#   '。。。。',
#   '▁>>>',
#   '\xad',
#   '»',
#   'いました',
#   '。2020',
#   'と考えます',
#   'だった',
#   'っていた',
#   '▁◆',
#   '▁▲',
#   'となる',
#   '▁Read',
#   'とう',
#   'というのを',
#   'です',
#   'と考えている',
#   '▁}',
#   '>',
#   '▁Next',
#   'してます',
#   '›',
#   '～',
#   '.......',
#   '一方',
#   'されます',
#   'なんだ',
#   'ーと',
#   '・・・」',
#   'も',
#   '-',
#   '!」',
#   '&',
#   '▁1',
#   'している',
#   'ぜ',
#   '}}}',
#   'けれど',
#   '次第',
#   '々',
#   '<',
#   '[1]',
#   'ということ',
#   '。2018',
#   'て',
#   'というところ',
#   'って',
#   'と言われる',
#   'と思っております',
#   'されています',
#   'けれども',
#   '☆',
#   'そうな',
#   '・',
#   'といって',
#   '◇',
#   '[1',
#   '続きを読む',
#   '!!!',
#   '。『',
#   '』',
#   'ーー',
#   '(8',
#   '▁2014',
#   'ようです',
#   'なと思いました',
#   '●',
#   '+',
#   'ーーー',
#   'w',
#   'などと',
#   '/',
#   '▁›',
#   '!...',
#   'っていること',
#   '≫',
#   '▁エ',
#   'し',
#   '[...]',
#   '～。',
#   '▁2013',
#   '▁<extra_id_2>',
#   '↓',
#   '\u202a',
#   'を獲得',
#   'せます',
#   '.[1]',
#   '}',
#   '♪',
#   '◆',
#   'と言っても',
#   'というもの',
#   'もん',
#   'ったこと',
#   'れます',
#   'だそうです',
#   'より',
#   '.”',
#   'ります',
#   '−',
#   '(4',
#   '〜',
#   '▁»',
#   '“',
#   'や',
#   'というのは',
#   'れています',
#   '▁W',
#   'とする',
#   'らし',
#   '}[',
#   'ラ',
#   '’’',
#   '▁<extra_id_55>',
#   'と',
#   '▁4',
#   '▁8',
#   'ている',
#   "''",
#   'という感じ',
#   'てます',
#   '▁「',
#   '........',
#   'された',
#   'シュ',
#   '「',
#   'ものです',
#   'が',
#   '▁また',
#   '▁2012',
#   '】【。】【',
#   'そうなので',
#   '▁<',
#   '▁6',
#   '#',
#   '▁។',
#   '.</',
#   '...(',
#   'とのこと',
#   ':',
#   '⇒',
#   'られました',
#   '(※',
#   '}(',
#   '<<',
#   '▁B',
#   '\x94',
#   '(#',
#   '▁※',
#   '▁<extra_id_54>',
#   '¡£¡',
#   '▁この',
#   'ていること',
#   '▁<extra_id_17>',
#   '様子',
#   'いじ',
#   '▁۔',
#   'して',
#   'のである',
#   '▲',
#   '(6',
#   '▽',
#   '▁M',
#   'とか',
#   '**',
#   '............',
#   'えた',
#   '▁Previous',
#   '▁2009',
#   '▁<extra_id_40>',
#   '։',
#   'のだ',
#   'さま',
#   '...」',
#   '▁Image',
#   'ことになります',
#   '...”',
#   'てた',
#   'エ',
#   'っております',
#   '<0xEE>',
#   'もの',
#   '▁http',
#   '!(',
#   '′′',
#   'け',
#   'ていた',
#   '။',
#   'しているという',
#   '▁2008',
#   '▁H',
#   '》',
#   'នោះ។',
#   '▁3',
#   '▁*',
#   'しております',
#   '—',
#   'していた',
#   '▁<extra_id_24>',
#   '動',
#   '[3]',
#   'います',
#   'ッ',
#   '>>>',
#   '▁12',
#   '^',
#   'ることが',
#   'こと',
#   '។',
#   'と判断',
#   '(+',
#   '››',
#   'H',
#   'ん',
#   '।',
#   '©',
#   '?',
#   '......」',
#   '——',
#   'ということが',
#   '(4)',
#   '▁14',
#   '▁17',
#   'え',
#   'けて',
#   'そうですね',
#   'ということで',
#   '•',
#   '▁□',
#   '落',
#   '▁11',
#   '...[',
#   '...!!',
#   '했다',
#   '(...)',
#   'というのも',
#   '▁#',
#   'ったのは',
#   'ァ',
#   'と思える',
#   '(11',
#   '▁↓',
#   'という話',
#   '中です',
#   'てて',
#   'を確認',
#   'あと',
#   '▁•',
#   '()',
#   '▁楽天',
#   '▁ちなみに',
#   '▁13',
#   'es',
#   'てしまいました',
#   '▁[1]',
#   'そ',
#   '{',
#   '@',
#   '۔',
#   'と思っていた',
#   '▁<extra_id_44>',
#   '▁---',
#   'と思ったら',
#   'され',
#   'ことが',
#   '格好',
#   '▁31',
#   '<0x00>',
#   'こ',
#   'くなっています',
#   '問題',
#   '!】',
#   'したのは',
#   '▁—',
#   'で',
#   '▁2013.',
#   '▁しかし',
#   '▁18',
#   '(7',
#   '──',
#   '▁16',
#   'ると',
#   '$',
#   'がついた',
#   'したこと',
#   '▁posted',
#   '<0xEF>',
#   '"}}}',
#   '▁そして',
#   '、、、',
#   'けた',
#   'としている',
#   '▁イン',
#   '今年の',
#   'わけです',
#   '(^^;',
#   '(0,',
#   '@@',
#   'Next',
#   '▁第',
#   '▁A',
#   '▁2012.',
#   '◎',
#   'リード',
#   '..........',
#   '(6)',
#   '▁--',
#   '(^',
#   'される',
#   'が進',
#   '▁0',
#   '▁★',
#   'ということを',
#   '▁29',
#   '▁2011',
#   'マーク',
#   'が決ま',
#   '<>',
#   '▁“',
#   'és',
#   'ことに',
#   '▁2014.',
#   '▁(4',
#   'コン',
#   'ほか',
#   'られます',
#   'んだ',
#   'ぁ',
#   '▁22',
#   '▁(29',
#   'になった',
#   '▁USA',
#   '▁2002',
#   'できました',
#   '.[1',
#   '(1',
#   '[2]',
#   'へ',
#   '▁2010',
#   '▁これは',
#   '(9',
#   '▁2005',
#   '】【。】【<】【/】【',
#   '事実',
#   '▁9',
#   'Posted',
#   '▁コメント',
#   'イ',
#   '.<',
#   'されて',
#   'a',
#   '[4]',
#   '▁<extra_id_50>',
#   '悪',
#   'ど',
#   'を記録',
#   '(3',
#   '、1',
#   'になりました',
#   'お',
#   '|||',
#   '."',
#   'オ',
#   'あ',
#   '状態',
#   '!!」',
#   '▁ロー',
#   '^^',
#   'と考える',
#   ']]',
#   '!!!!',
#   '▁7',
#   'そうですが',
#   '(0',
#   '▁</',
#   '▁さて',
#   'ワッ',
#   'れ',
#   '━',
#   'ัพ',
#   '〔',
#   'を',
#   'これ',
#   'wwwwwwwww',
#   '▁ホーム',
#   '▁Wednesday',
#   'ってしまいました',
#   'により',
#   '▁ハイ',
#   '▁(3',
#   'ザ',
#   '▁<extra_id_39>',
#   '過',
#   'いた',
#   '▁(8',
#   '&#160;',
#   '(1,',
#   ',”',
#   '▁(2014',
#   '▁▶',
#   '">',
#   '።',
#   '△',
#   '▁2018',
#   '\u202d',
#   'A',
#   'が決定',
#   '▁2004',
#   '▁–',
#   '▁2016',
#   '▁(#',
#   '▁2',
#   'ゝ',
#   '’',
#   'を果た',
#   '」、',
#   'とされる',
#   'ヤ',
#   '▁"',
#   '▁投稿日',
#   'と思います',
#   'こう',
#   'なのです',
#   '▁//',
#   'ただ',
#   '▁<extra_id_46>',
#   '」「',
#   '▁2017',
#   'アピール',
#   'るという',
#   '(1)',
#   '今年',
#   'ことを',
#   '予定です',
#   '▁<extra_id_41>',
#   '▁(2)',
#   '했습니다',
#   'ましたね',
#   '▁Tagged',
#   'ため',
#   'イチ',
#   '.[2]',
#   'ことになりました',
#   'ベスト',
#   '▁Home',
#   'てる',
#   '▁tweet',
#   '!”',
#   '▁20',
#   '▁2015',
#   'そうに',
#   '▁2007',
#   'hena',
#   'この',
#   'っていう',
#   ';',
#   'ed',
#   'と感じた',
#   '去年',
#   'したという',
#   'っけ',
#   '▁1991',
#   '▁○',
#   'ぶ',
#   'ナー',
#   '(3)',
#   '...!',
#   'ゾ',
#   '▁人気',
#   '▁<extra_id_43>',
#   'でしたね',
#   '[2',
#   '▁www',
#   'となっております',
#   "'",
#   '▁(1)',
#   'わ',
#   '結果',
#   '、【',
#   'からです',
#   'ネ',
#   '収',
#   '***',
#   '、4',
#   '«',
#   '▁10',
#   'ろ',
#   '▁5',
#   '決定',
#   '〈',
#   '(12',
#   '銆',
#   'たこと',
#   'カン',
#   '形',
#   'っており',
#   '(5',
#   '▁Tags',
#   '昨年',
#   'していること',
#   'れる',
#   'のだから',
#   'とともに',
#   '"}}',
#   '.[3]',
#   '▁―',
#   '▁NEW',
#   'ヽ',
#   'されている',
#   'B',
#   '▁28',
#   'ばかり',
#   '[1].',
#   '▁[#',
#   '▁新',
#   'と感じる',
#   '!=',
#   '▁(1',
#   'ところで',
#   '▁The',
#   '▁franc',
#   '-----',
#   '▁サ',
#   '▁Save',
#   'なんてこと',
#   '▁last',
#   'などが',
#   'を表示',
#   '、3',
#   '▁◇',
#   '£',
#   '▁21',
#   'るもの',
#   '▁15',
#   'しましたが',
#   '」【',
#   '▁J',
#   'せた',
#   'アナ',
#   '..."',
#   'ことになる',
#   '▁(19',
#   '中',
#   'みたいです',
#   'いきました',
#   '[6]',
#   'また',
#   '人気',
#   'ビ',
#   '▁2006',
#   'したので',
#   '▁1990',
#   '[7]',
#   '▁27',
#   'ハ',
#   '▁26',
#   '...........',
#   'カ',
#   '▁(2',
#   '▁’’',
#   '▁2009.',
#   'ペン',
#   'せる',
#   '▁1988',
#   'とき',
#   '模様',
#   'がつく',
#   '▁+',
#   'み',
#   '▁(27',
#   '(16',
#   'ခဲ့ပါတယ္။',
#   '###',
#   'ニ',
#   '(@',
#   'ヨ',
#   'してました',
#   'もや',
#   '▁——',
#   'んな',
#   '円',
#   'を掲載',
#   'られています',
#   '▁パ',
#   '▁Thursday',
#   'っているので',
#   '上で',
#   '一日',
#   '▁\u202a',
#   'het',
#   'う',
#   '▁{',
#   '▁(15',
#   '‐',
#   '▁1996',
#   '▁{{',
#   '〜。',
#   'ものの',
#   '▁△',
#   'さ',
#   'опада',
#   'デ',
#   'まして',
#   'nyana',
#   'らしい',
#   '”.',
#   'nega',
#   '(^^)',
#   '■■',
#   'が登場',
#   'しており',
#   '▁Tuesday',
#   'ろう',
#   'してきました',
#   '\xad\xad',
#   '><',
#   '!【',
#   '左',
#   'まり',
#   'く',
#   '←',
#   '%%',
#   'コー',
#   'って言って',
#   'ろうと',
#   'してしまいました',
#   '▁19',
#   '▁U',
#   '、「',
#   '〉',
#   '▁T',
#   '▁Page',
#   '経験',
#   'してから',
#   '▁1983',
#   '死',
#   'r',
#   'と思うんです',
#   'ら',
#   '(^_^)',
#   '1',
#   '▁平成',
#   '▁1.',
#   '[8]',
#   '▁in',
#   'んです',
#   '▁2020',
#   '▁C',
#   '▁2015.',
#   '\x9d',
#   '～～～～',
#   '▁<extra_id_33>',
#   'は',
#   'らなかった',
#   'したことが',
#   '▁23',
#   '▁EPA',
#   '▁25',
#   'を覚え',
#   'eba',
#   '▁ID',
#   'いませんでした',
#   '.[6]',
#   '¬',
#   '(*^',
#   '▁«',
#   '.’’',
#   '▁スリ',
#   'を紹介',
#   'なのだ',
#   '○',
#   '▁Get',
#   '(2',
#   'と見',
#   'になります',
#   '【】',
#   '▁$',
#   '▁激安',
#   '位',
#   'ることを',
#   '▁(13',
#   'ヒット',
#   'era',
#   '状況',
#   '▁1982',
#   '(30',
#   '】[',
#   '.............',
#   '日',
#   '▁($',
#   '▁(17',
#   'J',
#   '.[4]',
#   '▁Wed',
#   '▁(12',
#   'ことができました',
#   '))',
#   '東',
#   '▁2003',
#   '▁24',
#   '"}]',
#   '確定',
#   '.—',
#   '.638',
#   'マ',
#   'されていました',
#   '","',
#   '(5)',
#   '▁{"',
#   ".''",
#   '▁Friday',
#   'わった',
#   '明らかに',
#   '歴史',
#   'という事',
#   'アマ',
#   'న్నారు',
#   'っていく',
#   'ウ',
#   'せ',
#   '[20]',
#   '▁<extra_id_23>',
#   'が流れ',
#   '×',
#   '】【',
#   '(>',
#   '{}',
#   '▁(2013',
#   '》。',
#   'があります',
#   'のようです',
#   '▁NY',
#   'バ',
#   '▁$1,',
#   'けん',
#   'Published',
#   '▁(4)',
#   '▁2019',
#   '⋆',
#   '議会',
#   '▁(6',
#   '写真を',
#   '}}',
#   '現在',
#   '//',
#   'W',
#   'なあ',
#   'たり',
#   '▁E',
#   '12',
#   '(10',
#   'セミ',
#   '▁HOME',
#   '"]',
#   'スタン',
#   'ア',
#   '▁(9',
#   '▁(18',
#   'の様子',
#   '敗',
#   '------------',
#   'っちゃ',
#   'えている',
#   '▁Facebook',
#   'シュー',
#   '.”—',
#   '▁2007.',
#   'wwwww',
#   '!!!!!',
#   '[14]',
#   'すら',
#   '▁Pre',
#   '▁(0)',
#   '▁1992',
#   'を務め',
#   'すると',
#   '[16]',
#   'と思うのですが',
#   'っと',
#   '▁1999',
#   'これは',
#   '▁4.',
#   '▁30',
#   '♩',
#   '▁1989',
#   '倒',
#   'h',
#   'ってしまう',
#   ',"',
#   '▁2016.',
#   '▁ユ',
#   'む',
#   'いち',
#   'j',
#   'っていない',
#   'ès',
#   'wed',
#   '▁NBA',
#   '▁1984',
#   '▁ア',
#   'たい',
#   '▁2010.',
#   'atia',
#   '°',
#   'チーム',
#   '▁(28',
#   '▁1993',
#   'たし',
#   'とはいえ',
#   'と同じ',
#   '▁the',
#   'それ',
#   '(2)',
#   '次は',
#   'フ',
#   '\ue004',
#   'めた',
#   '20',
#   'られる',
#   '21',
#   '▁6-2',
#   '৷',
#   '後に',
#   'ことになった',
#   'ニュース',
#   '...............',
#   ...]]
