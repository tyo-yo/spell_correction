# %%
# %cd ../../spell_correction
# Out:
# /Users/tyoyo/lab/spell_correction

# %%
from spell_correction.t5_spell_corrector import T5SpellCorrector

# %%
import pandas as pd

# %%
spell_corrector = T5SpellCorrector(model_name='google/mt5-large')

# %%
def to_df(beams):
    jsons = [beam.dict() for beam in beams]
    return pd.DataFrame(sorted(jsons, key=lambda json: json['total_log_likelihood'], reverse=True))

# %% [markdown]
# * "彼はファヴローにクラッシック西部劇映画を提供した。", # 'クラッシック' → 'クラシック'
# * "民主党の予備選挙ではヒラリー・クリントンが1位となり、バラク・オバマが僅差の2位だた。",  # 'だた' → 'だった'
# * "クラゲには4つ放射管を持つが触手はもたない。",  # '' -> 'の'
# * "桶狭間の戦いで国友制の鉄砲が織田信長により初めて戦力として使用された。",  # '制' → '製'
# * "ひきこもりの更正をはじめたきっかけ",  # '正' → '生'

# %%
beams = spell_corrector.beam_search("彼はファヴローに <extra_id_0>西部劇映画を提供した。", original_token="クラッシック")
to_df(beams)
# Out:
#                         masked_text remaining_text filled_text  \
# 0  彼はファヴローに <extra_id_0>西部劇映画を提供した。                      クラシック
# 1  彼はファヴローに <extra_id_0>西部劇映画を提供した。                      ラッシック
# 2  彼はファヴローに <extra_id_0>西部劇映画を提供した。                      ラッパック
# 3  彼はファヴローに <extra_id_0>西部劇映画を提供した。                      ラッドック
# 4  彼はファヴローに <extra_id_0>西部劇映画を提供した。                      ラッシック
# 5  彼はファヴローに <extra_id_0>西部劇映画を提供した。                     ラッシットク
# 6  彼はファヴローに <extra_id_0>西部劇映画を提供した。                     ラッシックス
# 7  彼はファヴローに <extra_id_0>西部劇映画を提供した。                     ラッシッリク
# 8  彼はファヴローに <extra_id_0>西部劇映画を提供した。                      ラッシック
# 9  彼はファヴローに <extra_id_0>西部劇映画を提供した。                     ラッシッック
#
#    total_distance  total_log_likelihood  \
# 0             1.0             -8.415932
# 1             1.0            -18.022366
# 2             2.0            -18.405426
# 3             2.0            -20.687639
# 4             1.0            -20.996712
# 5             2.0            -22.909058
# 6             2.0            -23.629867
# 7             2.0            -28.323697
# 8             1.0            -30.329824
# 9             2.0            -31.975597
#
#                                              changes
# 0  [{'text_after': 'クラシック', 'text_before': 'クラッシッ...
# 1  [{'text_after': 'ラッ', 'text_before': 'クラッ', 'd...
# 2  [{'text_after': 'ラッ', 'text_before': 'クラッ', 'd...
# 3  [{'text_after': 'ラッ', 'text_before': 'クラッ', 'd...
# 4  [{'text_after': 'ラッ', 'text_before': 'クラッ', 'd...
# 5  [{'text_after': 'ラッ', 'text_before': 'クラッ', 'd...
# 6  [{'text_after': 'ラッ', 'text_before': 'クラッ', 'd...
# 7  [{'text_after': 'ラッ', 'text_before': 'クラッ', 'd...
# 8  [{'text_after': 'ラッ', 'text_before': 'クラッ', 'd...
# 9  [{'text_after': 'ラッ', 'text_before': 'クラッ', 'd...

# %%
beams = spell_corrector.beam_search("民主党の予備選挙ではヒラリー・クリントンが1位となり、バラク・オバマが僅差の2位 <extra_id_0>。", original_token="だた")
to_df(beams)
# Out:
#                                          masked_text remaining_text  \
# 0  民主党の予備選挙ではヒラリー・クリントンが1位となり、バラク・オバマが僅差の2位 <extr...
# 1  民主党の予備選挙ではヒラリー・クリントンが1位となり、バラク・オバマが僅差の2位 <extr...
# 2  民主党の予備選挙ではヒラリー・クリントンが1位となり、バラク・オバマが僅差の2位 <extr...
# 3  民主党の予備選挙ではヒラリー・クリントンが1位となり、バラク・オバマが僅差の2位 <extr...
# 4  民主党の予備選挙ではヒラリー・クリントンが1位となり、バラク・オバマが僅差の2位 <extr...
# 5  民主党の予備選挙ではヒラリー・クリントンが1位となり、バラク・オバマが僅差の2位 <extr...
# 6  民主党の予備選挙ではヒラリー・クリントンが1位となり、バラク・オバマが僅差の2位 <extr...
# 7  民主党の予備選挙ではヒラリー・クリントンが1位となり、バラク・オバマが僅差の2位 <extr...
# 8  民主党の予備選挙ではヒラリー・クリントンが1位となり、バラク・オバマが僅差の2位 <extr...
# 9  民主党の予備選挙ではヒラリー・クリントンが1位となり、バラク・オバマが僅差の2位 <extr...
#
#   filled_text  total_distance  total_log_likelihood  \
# 0         だった             1.0             -4.180431
# 1         とした             2.0             -8.915988
# 2        だとみた             2.0            -12.354361
# 3        だとした             2.0            -14.261576
# 4        だ。▁た             2.0            -15.318976
# 5          だた             0.0            -16.358049
# 6         だした             1.0            -16.759713
# 7        だ。また             2.0            -19.311717
# 8         だとた             1.0            -20.831622
# 9         だ。た             1.0            -25.060122
#
#                                              changes
# 0  [{'text_after': 'だった', 'text_before': 'だた', 'd...
# 1  [{'text_after': 'と', 'text_before': '', 'dista...
# 2  [{'text_after': 'だと', 'text_before': 'だ', 'dis...
# 3  [{'text_after': 'だと', 'text_before': 'だ', 'dis...
# 4  [{'text_after': 'だ', 'text_before': 'だ', 'dist...
# 5  [{'text_after': 'だ', 'text_before': 'だ', 'dist...
# 6  [{'text_after': 'だ', 'text_before': 'だ', 'dist...
# 7  [{'text_after': 'だ', 'text_before': 'だ', 'dist...
# 8  [{'text_after': 'だと', 'text_before': 'だ', 'dis...
# 9  [{'text_after': 'だ', 'text_before': 'だ', 'dist...

# %%
beams = spell_corrector.beam_search("クラゲには <extra_id_0>を持つが触手はもたない。", original_token="4つ放射管")
to_df(beams)
# Out:
#                       masked_text remaining_text filled_text  total_distance  \
# 0  クラゲには <extra_id_0>を持つが触手はもたない。                      14放射管             2.0
# 1  クラゲには <extra_id_0>を持つが触手はもたない。                     14手放射管             2.0
# 2  クラゲには <extra_id_0>を持つが触手はもたない。                    14つを放射管             2.0
# 3  クラゲには <extra_id_0>を持つが触手はもたない。                    14つ放射線管             2.0
# 4  クラゲには <extra_id_0>を持つが触手はもたない。                     14つ放射管             1.0
# 5  クラゲには <extra_id_0>を持つが触手はもたない。                    14つ放反射管             2.0
# 6  クラゲには <extra_id_0>を持つが触手はもたない。                     14つ放血管             2.0
# 7  クラゲには <extra_id_0>を持つが触手はもたない。                    14つ放射血管             2.0
# 8  クラゲには <extra_id_0>を持つが触手はもたない。                     14つ放射管             1.0
# 9  クラゲには <extra_id_0>を持つが触手はもたない。                    14つ放射血管             2.0
#
#    total_log_likelihood                                            changes
# 0            -22.067787  [{'text_after': '14', 'text_before': '4', 'dis...
# 1            -23.501163  [{'text_after': '14', 'text_before': '4', 'dis...
# 2            -30.086238  [{'text_after': '14', 'text_before': '4', 'dis...
# 3            -31.491088  [{'text_after': '14', 'text_before': '4', 'dis...
# 4            -36.607698  [{'text_after': '14', 'text_before': '4', 'dis...
# 5            -37.111666  [{'text_after': '14', 'text_before': '4', 'dis...
# 6            -38.642974  [{'text_after': '14', 'text_before': '4', 'dis...
# 7            -39.549357  [{'text_after': '14', 'text_before': '4', 'dis...
# 8            -43.206078  [{'text_after': '14', 'text_before': '4', 'dis...
# 9            -46.147737  [{'text_after': '14', 'text_before': '4', 'dis...

# %%
beams = spell_corrector.beam_search("桶狭間の戦いで <extra_id_0>の鉄砲が織田信長により初めて戦力として使用された。", original_token="国友制")
to_df(beams)
# Out:
#                                       masked_text remaining_text filled_text  \
# 0   桶狭間の戦いで <extra_id_0>の鉄砲が織田信長により初めて戦力として使用された。                       好友の制
# 1   桶狭間の戦いで <extra_id_0>の鉄砲が織田信長により初めて戦力として使用された。                        国法制
# 2   桶狭間の戦いで <extra_id_0>の鉄砲が織田信長により初めて戦力として使用された。                        好友制
# 3   桶狭間の戦いで <extra_id_0>の鉄砲が織田信長により初めて戦力として使用された。                       好友制作
# 4   桶狭間の戦いで <extra_id_0>の鉄砲が織田信長により初めて戦力として使用された。                        国友制
# 5   桶狭間の戦いで <extra_id_0>の鉄砲が織田信長により初めて戦力として使用された。                      国女友郎制
# 6   桶狭間の戦いで <extra_id_0>の鉄砲が織田信長により初めて戦力として使用された。                       国友制度
# 7   桶狭間の戦いで <extra_id_0>の鉄砲が織田信長により初めて戦力として使用された。                       国友社制
# 8   桶狭間の戦いで <extra_id_0>の鉄砲が織田信長により初めて戦力として使用された。                       国女友制
# 9   桶狭間の戦いで <extra_id_0>の鉄砲が織田信長により初めて戦力として使用された。                      国友社制定
# 10  桶狭間の戦いで <extra_id_0>の鉄砲が織田信長により初めて戦力として使用された。                      国女友制造
#
#     total_distance  total_log_likelihood  \
# 0              2.0            -17.782239
# 1              1.0            -19.381369
# 2              1.0            -22.235602
# 3              2.0            -23.749440
# 4              0.0            -23.768868
# 5              2.0            -26.060740
# 6              1.0            -26.292849
# 7              1.0            -28.391315
# 8              1.0            -29.710943
# 9              2.0            -30.995251
# 10             2.0            -31.020020
#
#                                               changes
# 0   [{'text_after': '好友', 'text_before': '国友', 'di...
# 1   [{'text_after': '国', 'text_before': '国', 'dist...
# 2   [{'text_after': '好友', 'text_before': '国友', 'di...
# 3   [{'text_after': '好友', 'text_before': '国友', 'di...
# 4   [{'text_after': '国', 'text_before': '国', 'dist...
# 5   [{'text_after': '国', 'text_before': '国', 'dist...
# 6   [{'text_after': '国', 'text_before': '国', 'dist...
# 7   [{'text_after': '国', 'text_before': '国', 'dist...
# 8   [{'text_after': '国', 'text_before': '国', 'dist...
# 9   [{'text_after': '国', 'text_before': '国', 'dist...
# 10  [{'text_after': '国', 'text_before': '国', 'dist...

# %%
# なぜか更生正とかになっているので、確認する
beams = spell_corrector.beam_search("ひきこもりからの <extra_id_0>をはじめたきっかけ", original_token="更正")
to_df(beams)
# Out:
#                       masked_text remaining_text filled_text  total_distance  \
# 0  ひきこもりからの <extra_id_0>をはじめたきっかけ                         矯正             1.0
# 1  ひきこもりからの <extra_id_0>をはじめたきっかけ                       更新▁正             2.0
# 2  ひきこもりからの <extra_id_0>をはじめたきっかけ                       更年期正             2.0
# 3  ひきこもりからの <extra_id_0>をはじめたきっかけ                         更正             0.0
# 4  ひきこもりからの <extra_id_0>をはじめたきっかけ                        脱真正             2.0
# 5  ひきこもりからの <extra_id_0>をはじめたきっかけ                        更新正             1.0
# 6  ひきこもりからの <extra_id_0>をはじめたきっかけ                         更新             2.0
# 7  ひきこもりからの <extra_id_0>をはじめたきっかけ                        更修正             1.0
# 8  ひきこもりからの <extra_id_0>をはじめたきっかけ                         更年             2.0
# 9  ひきこもりからの <extra_id_0>をはじめたきっかけ                        更年正             1.0
#
#    total_log_likelihood                                            changes
# 0             -9.542669  [{'text_after': '矯正', 'text_before': '更正', 'di...
# 1            -10.027076  [{'text_after': '更新', 'text_before': '更', 'dis...
# 2            -10.116961  [{'text_after': '更', 'text_before': '更', 'dist...
# 3            -14.305964  [{'text_after': '更', 'text_before': '更', 'dist...
# 4            -15.870855  [{'text_after': '脱', 'text_before': '', 'dista...
# 5            -19.678070  [{'text_after': '更新', 'text_before': '更', 'dis...
# 6            -20.070021  [{'text_after': '更新', 'text_before': '更', 'dis...
# 7            -21.368171  [{'text_after': '更', 'text_before': '更', 'dist...
# 8            -24.600758  [{'text_after': '更', 'text_before': '更', 'dist...
# 9            -28.554423  [{'text_after': '更', 'text_before': '更', 'dist...

# %%
# あと、distance=2に先になってしまいskipした場合のlog_likelihoodが正しく出ていないのでそれも出す。

# %%
beams = spell_corrector.beam_search("", original_token="")
to_df(beams)
